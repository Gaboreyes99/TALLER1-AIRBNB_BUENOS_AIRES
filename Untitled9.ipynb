# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
calendar = pd.read_csv('calendar.csv')
vecindarios = pd.read_csv('vecindarios.csv')
listings = pd.read_csv('listings.csv')
reviews = pd.read_csv('reviews.csv')
listings1 = pd.read_csv('listings1.csv')
reviews1 = pd.read_csv('reviews1.csv')

# %%
listings.head()
# Out:
#       id                                               name   host_id  \
# 0  11508  Condo in Buenos Aires · ★4.81 · 1 bedroom · 1 ...     42762
# 1  14222  Rental unit in Palermo/Buenos Aires · ★4.78 · ...  87710233
# 2  15074  Rental unit in Buenos Aires · 1 bedroom · 1 be...     59338
# 3  16695  Loft in Buenos Aires · ★4.28 · 1 bedroom · 1 b...     64880
# 4  20062  Rental unit in Buenos Aires · ★4.93 · 2 bedroo...     75891
#
#        host_name  neighbourhood_group neighbourhood   latitude  longitude  \
# 0        Candela                  NaN       Palermo -34.581840 -58.424150
# 1          María                  NaN       Palermo -34.586170 -58.410360
# 2         Monica                  NaN         Nuñez -34.538920 -58.465990
# 3  Elbio Mariano                  NaN     Monserrat -34.614390 -58.376110
# 4  Sergio Damian                  NaN       Palermo -34.581848 -58.441605
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
listings.describe(include=['O'])
# Out:
#                                                      name host_name  \
# count                                               26204     26204
# unique                                              13038      3404
# top     Rental unit in Buenos Aires · ★New · 1 bedroom...     Pablo
# freq                                                  880       382
#
#        neighbourhood        room_type last_review license
# count          26204            26204       21260     411
# unique            48                4        1495     395
# top          Palermo  Entire home/apt  2023-06-19  123456
# freq            8800            23556        1018       3

# %%
listings.groupby(['neighbourhood']).count()['last_review']
# Out:
# neighbourhood
# Agronomia              32
# Almagro               722
# Balvanera             669
# Barracas              161
# Belgrano             1102
# Boca                   59
# Boedo                  63
# Caballito             363
# Chacarita             343
# Coghlan                68
# Colegiales            492
# Constitucion          277
# Flores                 81
# Floresta               21
# Liniers                13
# Mataderos              14
# Monserrat             853
# Monte Castro            6
# Nueva Pompeya           7
# Nuñez                 466
# Palermo              7410
# Parque Avellaneda       4
# Parque Chacabuco       50
# Parque Chas            42
# Parque Patricios       47
# Paternal               24
# Puerto Madero         233
# Recoleta             3268
# Retiro               1004
# Saavedra              137
# San Cristobal          98
# San Nicolas          1293
# San Telmo             603
# Velez Sarsfield         8
# Versalles               1
# ...

# %%
listings.groupby(['neighbourhood']).count()['license']
# Out:
# neighbourhood
# Agronomia             2
# Almagro              23
# Balvanera            19
# Barracas              7
# Belgrano             26
# Boca                  2
# Boedo                 2
# Caballito             7
# Chacarita             5
# Coghlan               1
# Colegiales           11
# Constitucion          4
# Flores                5
# Floresta              0
# Liniers               0
# Mataderos             0
# Monserrat            17
# Monte Castro          1
# Nueva Pompeya         0
# Nuñez                11
# Palermo              95
# Parque Avellaneda     0
# Parque Chacabuco      2
# Parque Chas           0
# Parque Patricios      1
# Paternal              0
# Puerto Madero         3
# Recoleta             54
# Retiro               23
# Saavedra              4
# San Cristobal         3
# San Nicolas          34
# San Telmo            15
# Velez Sarsfield       0
# Versalles             0
# Villa Crespo         18
# Villa Del Parque      2
# ...

# %%
listings.groupby(['neighbourhood','name']).count()['license']
# Out:
# neighbourhood  name
# Agronomia      Condo in Agronomía · ★4.82 · 1 bedroom · 3 beds · 2.5 baths               0
#                Condo in Buenos Aires · 1 bedroom · 1 bed · 1 bath                        0
#                Condo in Buenos Aires · ★New · Studio · 2 beds · 1 bath                   0
#                Condo in Villa del Parque · ★4.71 · 1 bedroom · 2 beds · 1 bath           0
#                Condo in Villa del Parque · ★4.80 · 1 bedroom · 2 beds · 1 bath           0
#                                                                                         ..
# Villa Urquiza  Vacation home in Villa Urquiza · ★4.67 · Studio · 1 bed · 1 bath          0
#                Vacation home in Villa Urquiza · ★4.79 · 1 bedroom · 1 bed · 1 bath       0
#                Vacation home in Villa Urquiza · ★4.80 · 1 bedroom · 1 bed · 1.5 baths    0
#                Vacation home in Villa Urquiza · ★4.86 · 1 bedroom · 1 bed · 1 bath       0
# ...

# %%
listings.groupby(['neighbourhood','room_type']).count()['license']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 listings.groupby(['neighbourhood','room_typ']).count()['license']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
#    8413 )
#
# ...

# %%
listings.groupby(['neighbourhood','room_type']).count()['license']
# Out:
# neighbourhood     room_type
# Agronomia         Entire home/apt     2
#                   Private room        0
# Almagro           Entire home/apt    21
#                   Hotel room          0
#                   Private room        2
#                                      ..
# Villa Santa Rita  Private room        0
# Villa Soldati     Private room        0
# Villa Urquiza     Entire home/apt     7
#                   Private room        0
#                   Shared room         0
# Name: license, Length: 134, dtype: int64

# %%
listings.groupby(['neighbourhood','room_type']).count()['last_review']
# Out:
# neighbourhood     room_type
# Agronomia         Entire home/apt     27
#                   Private room         5
# Almagro           Entire home/apt    617
#                   Hotel room           0
#                   Private room       102
#                                     ...
# Villa Santa Rita  Private room         1
# Villa Soldati     Private room         0
# Villa Urquiza     Entire home/apt    222
#                   Private room        15
#                   Shared room          1
# Name: last_review, Length: 134, dtype: int64

# %%
grouped_bourhood = listings.groupby(['neighbourhood','room_type']).count()['last_review']
print(grouped_bourhood)
(grouped_bourhood.unstack(level=0).plot.bar())
plt.show()
# Out:
# neighbourhood     room_type
# Agronomia         Entire home/apt     27
#                   Private room         5
# Almagro           Entire home/apt    617
#                   Hotel room           0
#                   Private room       102
#                                     ...
# Villa Santa Rita  Private room         1
# Villa Soldati     Private room         0
# Villa Urquiza     Entire home/apt    222
#                   Private room        15
#                   Shared room          1
# Name: last_review, Length: 134, dtype: int64

# %%
listings.groupby(['neighbourhood']).count()['room_type']
# Out:
# neighbourhood
# Agronomia              40
# Almagro               933
# Balvanera             847
# Barracas              205
# Belgrano             1417
# Boca                   88
# Boedo                  85
# Caballito             513
# Chacarita             431
# Coghlan                94
# Colegiales            623
# Constitucion          335
# Flores                124
# Floresta               37
# Liniers                19
# Mataderos              21
# Monserrat            1045
# Monte Castro           11
# Nueva Pompeya          11
# Nuñez                 601
# Palermo              8800
# Parque Avellaneda       7
# Parque Chacabuco       68
# Parque Chas            61
# Parque Patricios       67
# Paternal               41
# Puerto Madero         299
# Recoleta             3893
# Retiro               1250
# Saavedra              188
# San Cristobal         139
# San Nicolas          1539
# San Telmo             709
# Velez Sarsfield        17
# Versalles               5
# ...

# %%
grouped_bourhood = listings.groupby(['neighbourhood','room_type']).count()['license']
print(grouped_bourhood)
(grouped_bourhood.unstack(level=0).plot.bar())
plt.show()
# Out:
# neighbourhood     room_type
# Agronomia         Entire home/apt     2
#                   Private room        0
# Almagro           Entire home/apt    21
#                   Hotel room          0
#                   Private room        2
#                                      ..
# Villa Santa Rita  Private room        0
# Villa Soldati     Private room        0
# Villa Urquiza     Entire home/apt     7
#                   Private room        0
#                   Shared room         0
# Name: license, Length: 134, dtype: int64

# %%
listings.groupby(['room_type']).count()['neighbourhood']
# Out:
# room_type
# Entire home/apt    23556
# Hotel room            99
# Private room        2343
# Shared room          206
# Name: neighbourhood, dtype: int64

# %%
grouped_bourhood = listings.groupby(['room_type']).count()['neighbourhood']
print(grouped_bourhood)
(grouped_bourhood.unstack(level=0).plot.bar())
plt.show()
# Out:
# room_type
# Entire home/apt    23556
# Hotel room            99
# Private room        2343
# Shared room          206
# Name: neighbourhood, dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 grouped_bourhood = listings.groupby(['room_type']).count()['neighbourhood']
#       2 print(grouped_bourhood)
# ----> 3 (grouped_bourhood.unstack(level=0).plot.bar())
#       4 plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4455, in Series.unstack(self, level, fill_value)
#    4412 """
#    4413 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4414
#    (...)
#    4451 b    2    4
#    4452 """
#    4453 from pandas.core.reshape.reshape import unstack
# -> 4455 return unstack(self, level, fill_value)
#
# ...

# %%
listings.plot.scatter(x="room_type", y="neighbourhood")
plt.show()

# %%
listings.describe(include=['O'])
# Out:
#                                                      name host_name  \
# count                                               26204     26204
# unique                                              13038      3404
# top     Rental unit in Buenos Aires · ★New · 1 bedroom...     Pablo
# freq                                                  880       382
#
#        neighbourhood        room_type last_review license
# count          26204            26204       21260     411
# unique            48                4        1495     395
# top          Palermo  Entire home/apt  2023-06-19  123456
# freq            8800            23556        1018       3

# %%
listings[['neighbourhood','room_type','last_review','license']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26204 entries, 0 to 26203
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   neighbourhood  26204 non-null  object
#  1   room_type      26204 non-null  object
#  2   last_review    21260 non-null  object
#  3   license        411 non-null    object
# dtypes: object(4)
# memory usage: 819.0+ KB

# %%
calendar.describe(include=['O'])
# Out:
#               date available      price adjusted_price
# count      9564447   9564447    9564447        9564447
# unique         366         2       6615           8823
# top     2023-06-29         t  $8,917.00      $8,917.00
# freq         26204   5609634     285010         273264

# %%
calendar.groupby(['price','adjusted_price','date']).count()['available']
# Out:
# price          adjusted_price  date
# $1,000,000.00  $1,000,000.00   2023-06-28    1
#                                2023-06-29    1
#                                2023-06-30    1
#                                2023-07-01    1
#                                2023-07-02    1
#                                             ..
# $999.00        $999.00         2024-06-23    1
#                                2024-06-24    1
#                                2024-06-25    1
#                                2024-06-26    1
#                                2024-06-27    1
# Name: available, Length: 721299, dtype: int64

# %%
grouped_calen = calendar.groupby(['price','date']).count()['available']
print(grouped_calen)
(grouped_calen.unstack(level=0).plot.bar())
plt.show()

# %%
calendar.plot.scatter(x="date", y="available")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
reviews.head()
# Out:
#    listing_id        date
# 0       11508  2012-07-02
# 1       11508  2012-12-26
# 2       11508  2013-01-05
# 3       11508  2013-07-28
# 4       11508  2013-12-22

# %%
reviews.describe()
# Out:
#          listing_id
# count  5.718600e+05
# mean   1.523683e+17
# std    2.933727e+17
# min    1.150800e+04
# 25%    1.502689e+07
# 50%    3.126255e+07
# 75%    5.261362e+07
# max    9.219057e+17

# %%
reviews1 = pd.read_csv('reviews1.csv')

# %%
reviews1.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0       11508  1615861  2012-07-02       877808       Charlie
# 1       11508  3157005  2012-12-26       656077        Shaily
# 2       11508  3281011  2013-01-05      2835998       Michiel
# 3       11508  6050019  2013-07-28      4600436          Tara
# 4       11508  9328455  2013-12-22      3130017         Simon
#
#                                             comments
# 0  Amazing place!\r<br/>\r<br/>Location: short wa...
# 1  Really enjoyed Candela's recommendations and q...
# 2  Candela and her colleague were very attentive ...
# 3  The apartment was in a beautiful, modern build...
# 4  My stay at Candela's apartment was very enjoya...

# %%
reviews1.describe()
# Out:
#          listing_id            id   reviewer_id
# count  5.718600e+05  5.718600e+05  5.718600e+05
# mean   1.523683e+17  4.313380e+17  1.680009e+08
# std    2.933727e+17  3.810591e+17  1.507216e+08
# min    1.150800e+04  4.403400e+04  1.000000e+00
# 25%    1.502689e+07  4.392309e+08  4.006871e+07
# 50%    3.126255e+07  5.883773e+17  1.220752e+08
# 75%    5.261362e+07  7.891023e+17  2.564149e+08
# max    9.219057e+17  9.239680e+17  5.221917e+08

# %%
reviews1.describe(include=['0'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 reviews1.describe(include=['0'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:10940, in NDFrame.describe(self, percentiles, include, exclude, datetime_is_numeric)
#   10691 @final
#   10692 def describe(
#   10693     self: NDFrameT,
#    (...)
#   10697     datetime_is_numeric: bool_t = False,
#   10698 ) -> NDFrameT:
#   10699     """
#   10700     Generate descriptive statistics.
#   10701
#    (...)
#   10938     max            NaN      3.0
#   10939     """
# > 10940     return describe_ndframe(
#   10941         obj=self,
#   10942         include=include,
#   10943         exclude=exclude,
#   10944         datetime_is_numeric=datetime_is_numeric,
#   10945         percentiles=percentiles,
#   10946     )
#
# ...
